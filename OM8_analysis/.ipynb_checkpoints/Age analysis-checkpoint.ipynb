# %%
# %reset
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import cartopy.crs as ccrs
import netCDF4 as nc
import matplotlib.ticker as mticker
import warnings; warnings.filterwarnings('ignore')
import cmocean
from gsw import alpha, SA_from_SP, p_from_z, CT_from_pt, beta, sigma1 
import pandas as pd
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
# %cd /archive/Raphael.Dussin/xanadu_esm4_20190304_mom6_2019.12.16/OM4p125_JRA55do1.4_mle3d_cycle3
# %cd gfdl.ncrc4-intel16-prod/pp/ocean_annual_z_d2/
fs=xr.open_dataset('ocean_annual_z_d2.static.nc')
deptho=fs['deptho'][:,:]
lon=fs['geolon']; lat=fs['geolat']
lonu=fs['geolon_u']; latu=fs['geolat_u']
lonv=fs['geolon_v']; latv=fs['geolat_v']
#print(fs)
# %cd av/annual_5yr
# Out:
# /arch2/rnd/xanadu_esm4_20190304_mom6_2019.12.16/OM4p125_JRA55do1.4_mle3d_cycle3
# /arch2/rnd/xanadu_esm4_20190304_mom6_2019.12.16/OM4p125_JRA55do1.4_mle3d_cycle3/gfdl.ncrc4-intel16-prod/pp/ocean_annual_z_d2
# /arch2/rnd/xanadu_esm4_20190304_mom6_2019.12.16/OM4p125_JRA55do1.4_mle3d_cycle3/gfdl.ncrc4-intel16-prod/pp/ocean_annual_z_d2/av/annual_5yr

# %%
def rebin(a, shape):
    sh = shape[0],a.shape[0]//shape[0],shape[1],a.shape[1]//shape[1]
    return a.reshape(sh).mean(-1).mean(1)

# %%
lonr=rebin(np.array(lon),(1120,1440))
latr=rebin(np.array(lat),(1120,1440))

# %%
data=xr.open_mfdataset('ocean_annual_z_d2.2003-2007.ann.nc')['time']
title=str(data[0].values); 
print(title)
yearly = xr.open_mfdataset(['ocean_annual_z_d2.2003-2007.ann.nc'])
fhist=yearly

agessc   = fhist.variables['agessc'][0,:,:,:]
z_l=fhist.variables['z_l'][:]
agessc.shape
# Out:
# 2005-07-02 00:00:00
# (35, 1120, 1440)

# %%
answer = np.empty((1120,1440)); answer[:] = np.NaN
for i in range(656,1120):
    for j in range(0,1440):
        df = pd.Series(agessc[:,i,j])
        final_index = df.last_valid_index()
        if final_index!=None:
            answer[i,j]=agessc[final_index,i,j]
            
    print(i)
# Out:
# 656
# 657
# 658
# 659
# 660
# 661
# 662
# 663
# 664
# 665
# 666
# 667
# 668
# 669
# 670
# 671
# 672
# 673
# 674
# 675
# 676
# 677
# 678
# 679
# 680
# 681
# 682
# 683
# 684
# 685
# 686
# 687
# 688
# 689
# 690
# 691
# 692
# 693
# 694
# 695
# 696
# 697
# 698
# 699
# 700
# 701
# 702
# 703
# 704
# 705
# 706
# 707
# 708
# 709
# 710
# 711
# 712
# 713
# 714
# 715
# 716
# 717
# 718
# 719
# 720
# 721
# 722
# 723
# 724
# 725
# 726
# 727
# 728
# 729
# 730
# 731
# 732
# 733
# 734
# 735
# 736
# 737
# 738
# 739
# 740
# 741
# 742
# 743
# 744
# 745
# 746
# 747
# 748
# 749
# 750
# 751
# 752
# 753
# 754
# 755
# 756
# 757
# 758
# 759
# 760
# 761
# 762
# 763
# 764
# 765
# 766
# 767
# 768
# 769
# 770
# 771
# 772
# 773
# 774
# 775
# 776
# 777
# 778
# 779
# 780
# 781
# 782
# 783
# 784
# 785
# 786
# 787
# 788
# 789
# 790
# 791
# 792
# 793
# 794
# 795
# 796
# 797
# 798
# 799
# 800
# 801
# 802
# 803
# 804
# 805
# 806
# 807
# 808
# 809
# 810
# 811
# 812
# 813
# 814
# 815
# 816
# 817
# 818
# 819
# 820
# 821
# 822
# 823
# 824
# 825
# 826
# 827
# 828
# 829
# 830
# 831
# 832
# 833
# 834
# 835
# 836
# 837
# 838
# 839
# 840
# 841
# 842
# 843
# 844
# 845
# 846
# 847
# 848
# 849
# 850
# 851
# 852
# 853
# 854
# 855
# 856
# 857
# 858
# 859
# 860
# 861
# 862
# 863
# 864
# 865
# 866
# 867
# 868
# 869
# 870
# 871
# 872
# 873
# 874
# 875
# 876
# 877
# 878
# 879
# 880
# 881
# 882
# 883
# 884
# 885
# 886
# 887
# 888
# 889
# 890
# 891
# 892
# 893
# 894
# 895
# 896
# 897
# 898
# 899
# 900
# 901
# 902
# 903
# 904
# 905
# 906
# 907
# 908
# 909
# 910
# 911
# 912
# 913
# 914
# 915
# 916
# 917
# 918
# 919
# 920
# 921
# 922
# 923
# 924
# 925
# 926
# 927
# 928
# 929
# 930
# 931
# 932
# 933
# 934
# 935
# 936
# 937
# 938
# 939
# 940
# 941
# 942
# 943
# 944
# 945
# 946
# 947
# 948
# 949
# 950
# 951
# 952
# 953
# 954
# 955
# 956
# 957
# 958
# 959
# 960
# 961
# 962
# 963
# 964
# 965
# 966
# 967
# 968
# 969
# 970
# 971
# 972
# 973
# 974
# 975
# 976
# 977
# 978
# 979
# 980
# 981
# 982
# 983
# 984
# 985
# 986
# 987
# 988
# 989
# 990
# 991
# 992
# 993
# 994
# 995
# 996
# 997
# 998
# 999
# 1000
# 1001
# 1002
# 1003
# 1004
# 1005
# 1006
# 1007
# 1008
# 1009
# 1010
# 1011
# 1012
# 1013
# 1014
# 1015
# 1016
# 1017
# 1018
# 1019
# 1020
# 1021
# 1022
# 1023
# 1024
# 1025
# 1026
# 1027
# 1028
# 1029
# 1030
# 1031
# 1032
# 1033
# 1034
# 1035
# 1036
# 1037
# 1038
# 1039
# 1040
# 1041
# 1042
# 1043
# 1044
# 1045
# 1046
# 1047
# 1048
# 1049
# 1050
# 1051
# 1052
# 1053
# 1054
# 1055
# 1056
# 1057
# 1058
# 1059
# 1060
# 1061
# 1062
# 1063
# 1064
# 1065
# 1066
# 1067
# 1068
# 1069
# 1070
# 1071
# 1072
# 1073
# 1074
# 1075
# 1076
# 1077
# 1078
# 1079
# 1080
# 1081
# 1082
# 1083
# 1084
# 1085
# 1086
# 1087
# 1088
# 1089
# 1090
# 1091
# 1092
# 1093
# 1094
# 1095
# 1096
# 1097
# 1098
# 1099
# 1100
# 1101
# 1102
# 1103
# 1104
# 1105
# 1106
# 1107
# 1108
# 1109
# 1110
# 1111
# 1112
# 1113
# 1114
# 1115
# 1116
# 1117
# 1118
# 1119

# %%
fig = plt.figure(figsize=(10, 10))
ax = plt.axes(projection=ccrs.Orthographic(0, 90))
ax.set_extent([-180, 180, 70, 90],ccrs.PlateCarree())

plt.pcolormesh(lonr, latr,np.ones((1120,1440)),transform=ccrs.PlateCarree(),cmap='gray',vmin=0,vmax=2);

plt.pcolormesh(lonr, latr,answer[:,:]/np.nanmax(answer),transform=ccrs.PlateCarree(),cmap=cmocean.cm.matter,vmin=0,vmax=1);

cbar=plt.colorbar(fraction=0.046, pad=0.04); cbar.ax.tick_params(labelsize=25);
gl=ax.gridlines(crs=ccrs.PlateCarree())
plt.title('Normalized age at bottom',fontsize=25)
gl.ylocator = mticker.FixedLocator([70, 75, 80, 85, 90])

ax.scatter(180, 90, marker='o',c='black', transform=ccrs.PlateCarree())
pointx=[0,0,0,0]; pointy=[70,75,80,85]; text=['70$^\circ$','75$^\circ$','80$^\circ$','85$^\circ$']
for i in range(len(pointx)):
    ax.text(pointx[i],pointy[i],text[i],ha='center', transform=ccrs.PlateCarree(),fontsize=16,color='black')

# %%
fig = plt.figure(figsize=(10, 10))
ax = plt.axes(projection=ccrs.Orthographic(0, 90))
ax.set_extent([-180, 180, 70, 90],ccrs.PlateCarree())

plt.pcolormesh(lon, lat,np.ones((1120,1440)),transform=ccrs.PlateCarree(),cmap='gray',vmin=0,vmax=2);

plt.pcolormesh(lon, lat,agessc[12,:,:]/np.nanmax(answer),transform=ccrs.PlateCarree(),cmap=cmocean.cm.matter,vmin=0,vmax=1);

cbar=plt.colorbar(fraction=0.046, pad=0.04); cbar.ax.tick_params(labelsize=25);
gl=ax.gridlines(crs=ccrs.PlateCarree())
plt.title('Normalized age at 400m',fontsize=25)
gl.ylocator = mticker.FixedLocator([70, 75, 80, 85, 90])

ax.scatter(180, 90, marker='o',c='black', transform=ccrs.PlateCarree())
pointx=[0,0,0,0]; pointy=[70,75,80,85]; text=['70$^\circ$','75$^\circ$','80$^\circ$','85$^\circ$']
for i in range(len(pointx)):
    ax.text(pointx[i],pointy[i],text[i],ha='center', transform=ccrs.PlateCarree(),fontsize=16,color='black')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-1021e2079c57> in <module>
#       3 ax.set_extent([-180, 180, 70, 90],ccrs.PlateCarree())
#       4
# ----> 5 plt.pcolormesh(lon, lat,np.ones((1120,1440)),transform=ccrs.PlateCarree(),cmap='gray',vmin=0,vmax=2);
#       6
#       7 plt.pcolormesh(lon, lat,agessc[12,:,:]/np.nanmax(answer),transform=ccrs.PlateCarree(),cmap=cmocean.cm.matter,vmin=0,vmax=1);
#
# /nbhome/eay/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in pcolormesh(alpha, norm, cmap, vmin, vmax, shading, antialiased, data, *args, **kwargs)
#    2755         *args, alpha=alpha, norm=norm, cmap=cmap, vmin=vmin,
#    2756         vmax=vmax, shading=shading, antialiased=antialiased,
# -> 2757         **({"data": data} if data is not None else {}), **kwargs)
#    2758     sci(__ret)
#    2759     return __ret
#
# /nbhome/eay/anaconda3/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py in pcolormesh(self, *args, **kwargs)
#    1457                              ' consider using PlateCarree/RotatedPole.')
#    1458         kwargs.setdefault('transform', t)
# -> 1459         result = self._pcolormesh_patched(*args, **kwargs)
#    1460         self.autoscale_view()
#    1461         return result
#
# /nbhome/eay/anaconda3/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py in _pcolormesh_patched(self, *args, **kwargs)
#    1489         allmatch = (shading == 'gouraud')
#    1490
# -> 1491         X, Y, C = self._pcolorargs('pcolormesh', *args, allmatch=allmatch)
#    1492         Ny, Nx = X.shape
#    1493
#
# /nbhome/eay/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in _pcolorargs(funcname, allmatch, *args)
#    5750                 raise TypeError('Dimensions of C %s are incompatible with'
#    5751                                 ' X (%d) and/or Y (%d); see help(%s)' % (
# -> 5752                                     C.shape, Nx, Ny, funcname))
#    5753             C = C[:Ny - 1, :Nx - 1]
#    5754         C = cbook.safe_masked_invalid(C)
#
# TypeError: Dimensions of C (1120, 1440) are incompatible with X (2880) and/or Y (2240); see help(pcolormesh)

# %%
fig = plt.figure(figsize=(10, 10))
ax = plt.axes(projection=ccrs.Orthographic(0, 90))
ax.set_extent([-180, 180, 70, 90],ccrs.PlateCarree())

plt.pcolormesh(lonr, latr,np.ones((1120,1440)),transform=ccrs.PlateCarree(),cmap='gray',vmin=0,vmax=2);

plt.pcolormesh(lonr, latr,agessc[12,:,:]/np.nanmax(answer),transform=ccrs.PlateCarree(),cmap=cmocean.cm.matter,vmin=0,vmax=1);

cbar=plt.colorbar(fraction=0.046, pad=0.04); cbar.ax.tick_params(labelsize=25);
gl=ax.gridlines(crs=ccrs.PlateCarree())
plt.title('Normalized age at 400m',fontsize=25)
gl.ylocator = mticker.FixedLocator([70, 75, 80, 85, 90])

ax.scatter(180, 90, marker='o',c='black', transform=ccrs.PlateCarree())
pointx=[0,0,0,0]; pointy=[70,75,80,85]; text=['70$^\circ$','75$^\circ$','80$^\circ$','85$^\circ$']
for i in range(len(pointx)):
    ax.text(pointx[i],pointy[i],text[i],ha='center', transform=ccrs.PlateCarree(),fontsize=16,color='black')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-4fc0d47e2987> in <module>
#       5 plt.pcolormesh(lonr, latr,np.ones((1120,1440)),transform=ccrs.PlateCarree(),cmap='gray',vmin=0,vmax=2);
#       6
# ----> 7 plt.pcolormesh(lonr, latr,agessc[12,:,:]/np.nanmax(answer),transform=ccrs.PlateCarree(),cmap=cmocean.cm.matter,vmin=0,vmax=1);
#       8
#       9 cbar=plt.colorbar(fraction=0.046, pad=0.04); cbar.ax.tick_params(labelsize=25);
#
# NameError: name 'answer' is not defined

# %%
# Out:
# <xarray.Variable ()>
# array(400.)
# Attributes:
#     long_name:       Depth at cell center
#     units:           meters
#     cartesian_axis:  Z
#     positive:        down
#     edges:           z_i
